# %% [markdown]
# 1.TimeIndex

# %%
import pandas as pd
df=pd.read_csv('aapl.csv')
df.head()
# Out:
#         Date    Open    High     Low   Close    Volume
# 0   7-Jul-17  142.90  144.75  142.90  144.18  19201712
# 1   6-Jul-17  143.02  143.50  142.41  142.73  24128782
# 2   5-Jul-17  143.69  144.79  142.72  144.09  21569557
# 3   3-Jul-17  144.88  145.30  143.10  143.50  14277848
# 4  30-Jun-17  144.45  144.96  143.78  144.02  23024107

# %%
df = pd.read_csv("aapl.csv",parse_dates=["Date"], index_col="Date")
#to convert this column into a datetime format n set date colum as the index of the DataFrame
df
# Out:
# C:\Users\Rajesh\AppData\Local\Temp\ipykernel_16156\3419178847.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("aapl.csv",parse_dates=["Date"], index_col="Date")
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# ...

# %%
df.index
#check missing date
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-06', '2017-07-05', '2017-07-03',
#                '2017-06-30', '2017-06-29', '2017-06-28', '2017-06-27',
#                '2017-06-26', '2017-06-23',
#                ...
#                '2016-07-22', '2016-07-21', '2016-07-20', '2016-07-19',
#                '2016-07-18', '2016-07-15', '2016-07-14', '2016-07-13',
#                '2016-07-12', '2016-07-11'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %% [markdown]
# What is DatetimeIndex? Benefits of it
# (1) Partial Date Index: Select Specific Months Data

# %%
df.loc['2017-06-30']
# Out:
# Open           144.45
# High           144.96
# Low            143.78
# Close          144.02
# Volume    23024107.00
# Name: 2017-06-30 00:00:00, dtype: float64

# %%
df.loc['2017-06-30', 'Open']
# Out:
# 144.45

# %%
df.loc['2017-06']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# 2017-06-29  144.71  145.13  142.28  143.68  31499368
# 2017-06-28  144.49  146.11  143.16  145.83  22082432
# 2017-06-27  145.01  146.16  143.62  143.73  24761891
# 2017-06-26  147.17  148.28  145.38  145.82  25692361
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# ...

# %%
df.loc['2017-06'].head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# 2017-06-29  144.71  145.13  142.28  143.68  31499368
# 2017-06-28  144.49  146.11  143.16  145.83  22082432
# 2017-06-27  145.01  146.16  143.62  143.73  24761891
# 2017-06-26  147.17  148.28  145.38  145.82  25692361

# %% [markdown]
# Average price of aapl's stock in June, 2017

# %%
df.loc['2017-06'].Close.mean()
# Out:
# 147.8313636363636

# %%
df.loc['2017-06'].describe()
# Out:
#              Open        High         Low       Close        Volume
# count   22.000000   22.000000   22.000000   22.000000  2.200000e+01
# mean   148.215000  149.088636  146.582727  147.831364  3.109900e+07
# std      4.450871    4.337027    4.507623    4.434315  1.416738e+07
# min    143.320000  144.480000  142.200000  142.270000  1.640409e+07
# 25%    144.785000  146.095000  143.630000  145.047500  2.231785e+07
# 50%    146.320000  147.015000  145.025000  145.850000  2.615864e+07
# 75%    153.477500  154.170000  150.670000  152.130000  3.244740e+07
# max    155.250000  155.980000  154.480000  155.450000  7.230733e+07

# %% [markdown]
# (2) Select Date Range

# %%
df.loc['2016-10-01':'2016-10-30']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2016-10-03  112.71  113.05  112.28  112.52  21701760
# 2016-10-04  113.06  114.31  112.63  113.00  29736835
# 2016-10-05  113.40  113.66  112.69  113.05  21453089
# 2016-10-06  113.70  114.34  113.13  113.89  28779313
# 2016-10-07  114.31  114.56  113.51  114.06  24358443
# 2016-10-10  115.02  116.75  114.72  116.05  36235956
# 2016-10-11  117.70  118.69  116.20  116.30  64041043
# 2016-10-12  117.35  117.98  116.75  117.34  37586787
# 2016-10-13  116.79  117.44  115.72  116.98  35192406
# 2016-10-14  117.88  118.17  117.13  117.63  35652191
# 2016-10-17  117.33  117.84  116.78  117.55  23624896
# 2016-10-18  118.18  118.21  117.45  117.47  24553478
# 2016-10-19  117.25  117.76  113.80  117.12  20034594
# 2016-10-20  116.86  117.38  116.33  117.06  24125801
# 2016-10-21  116.81  116.91  116.28  116.60  23192665
# 2016-10-24  117.10  117.74  117.00  117.65  23538673
# 2016-10-25  117.95  118.36  117.31  118.25  48128970
# ...

# %%
df['Close'].resample('M').mean()
#check on Monthly frequencyof  average close
# Out:
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: M, Name: Close, dtype: float64

# %%
# %matplotlib inline
df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close'].resample('M').mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
#press shift + tab to check on resample frequency

# %%
df['Close'].resample('Q').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close'].resample('M').mean().plot()
# Out:
# <Axes: xlabel='Date'>
