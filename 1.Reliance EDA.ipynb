# %%
#pip install yfinance

# %%
#pip install nsepy

# %%
from Descriptive import Descriptive

# %%
obj=Descriptive()

# %%
from nsepy import get_history as gh
import datetime as dt
import yfinance as yf
stock_symbol="RELIANCE.NS"#NSE stock usually end with.NS
#download stock data
stk_data=yf.download(stock_symbol,start="2023-01-01",end="2023-07-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stk_data.info
# Out:
# <bound method DataFrame.info of Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2023-01-02  1172.422974  1173.833955  1159.815273  1160.634533     5316175
# 2023-01-03  1163.843384  1171.103078  1159.633312  1167.484608     7658932
# 2023-01-04  1146.319946  1165.663880  1144.248981  1163.820454     9264891
# 2023-01-05  1144.271851  1154.444524  1139.697597  1148.573058    13637099
# 2023-01-06  1154.671997  1159.701449  1146.206227  1150.006728     6349597
# ...                 ...          ...          ...          ...         ...
# 2023-06-23  1144.590576  1153.079101  1143.338871  1151.030890     6628570
# 2023-06-26  1135.851685  1144.886424  1132.733920  1141.063168    12641159
# 2023-06-27  1136.261353  1142.200960  1131.800868  1136.306860     9689466
# 2023-06-28  1151.303955  1155.104456  1136.898337  1143.793968    11354006
# 2023-06-30  1160.748291  1163.661270  1153.101781  1158.996001    11151555
#
# [122 rows x 5 columns]>

# %%
stk_data
# Out:
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2023-01-02  1172.422974  1173.833955  1159.815273  1160.634533     5316175
# 2023-01-03  1163.843384  1171.103078  1159.633312  1167.484608     7658932
# 2023-01-04  1146.319946  1165.663880  1144.248981  1163.820454     9264891
# 2023-01-05  1144.271851  1154.444524  1139.697597  1148.573058    13637099
# 2023-01-06  1154.671997  1159.701449  1146.206227  1150.006728     6349597
# ...                 ...          ...          ...          ...         ...
# 2023-06-23  1144.590576  1153.079101  1143.338871  1151.030890     6628570
# 2023-06-26  1135.851685  1144.886424  1132.733920  1141.063168    12641159
# 2023-06-27  1136.261353  1142.200960  1131.800868  1136.306860     9689466
# 2023-06-28  1151.303955  1155.104456  1136.898337  1143.793968    11354006
# 2023-06-30  1160.748291  1163.661270  1153.101781  1158.996001    11151555
#
# [122 rows x 5 columns]

# %%
dataset=stk_data
quan,qual=obj.segreQuanQual(dataset)
# Out:
# The Quantitative Data: [('Close', 'RELIANCE.NS'), ('High', 'RELIANCE.NS'), ('Low', 'RELIANCE.NS'), ('Open', 'RELIANCE.NS'), ('Volume', 'RELIANCE.NS')]
# The Qualtitative Data []

# %%
des_data=obj.descriptive_Analysis(dataset,quan)

# %%
des_data
# Out:
#               (Close, RELIANCE.NS) (High, RELIANCE.NS) (Low, RELIANCE.NS)  \
# Null_count                       0                   0                  0
# NonNull_count                  122                 122                122
# Total_Count                    122                 122                122
# Mean                   1098.261887         1107.204296        1090.087266
# Median                 1106.096069         1113.241998        1097.584704
# Mode                   1001.900696         1010.434788         992.228728
# Std                      42.855773           41.700961            43.3439
# Min                    1001.900696         1010.434788         992.228728
# Q1:25%                 1065.991577         1074.235547        1056.865796
# Q2:50%                 1106.096069         1113.241998        1097.584704
# Q3:75%                 1129.473846         1137.859995        1121.747524
# Q4:100%                1181.935547         1186.122956        1165.277051
# IQR                      63.482269           63.624448          64.881728
# 1.5Rule                  95.223404           95.436672          97.322592
# Lesser                  970.768173          978.798874         959.543204
# Greater                 1224.69725         1233.296667        1219.070115
#
#               (Open, RELIANCE.NS) (Volume, RELIANCE.NS)
# Null_count                      0                     0
# NonNull_count                 122                   122
# Total_Count                   122                   122
# Mean                  1100.205237       13045123.737705
# Median                1105.982331            11680332.5
# Mode                  1008.159038               5316175
# Std                     42.255711        5569096.501439
# Min                   1008.159038             5316175.0
# Q1:25%                1069.166221            9243317.25
# Q2:50%                1105.982331            11680332.5
# Q3:75%                1132.950057           15457766.25
# Q4:100%               1186.122956            34014213.0
# IQR                     63.783837             6214449.0
# 1.5Rule                 95.675755             9321673.5
# Lesser                 973.490466             -78356.25
# Greater               1228.625812           24779439.75

# %%
des_data[('Low', 'RELIANCE.NS')]
# Out:
# Null_count                 0
# NonNull_count            122
# Total_Count              122
# Mean             1090.087266
# Median           1097.584704
# Mode              992.228728
# Std                  43.3439
# Min               992.228728
# Q1:25%           1056.865796
# Q2:50%           1097.584704
# Q3:75%           1121.747524
# Q4:100%          1165.277051
# IQR                64.881728
# 1.5Rule            97.322592
# Lesser            959.543204
# Greater          1219.070115
# Name: (Low, RELIANCE.NS), dtype: object

# %%
des_data[('High', 'RELIANCE.NS')]
# Out:
# Null_count                 0
# NonNull_count            122
# Total_Count              122
# Mean             1107.204296
# Median           1113.241998
# Mode             1010.434788
# Std                41.700961
# Min              1010.434788
# Q1:25%           1074.235547
# Q2:50%           1113.241998
# Q3:75%           1137.859995
# Q4:100%          1186.122956
# IQR                63.624448
# 1.5Rule            95.436672
# Lesser            978.798874
# Greater          1233.296667
# Name: (High, RELIANCE.NS), dtype: object

# %%
import numpy as np

# %%
np.percentile(dataset[('Low', 'RELIANCE.NS')],99)
# Out:
# 1159.7961768039004

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(des_data['Low','RELIANCE.NS'],30,600)
# Out:
# C:\Users\Rajesh\AppData\Local\Temp\ipykernel_11624\132380739.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=702.610, Standard Deviation=506.851
# The area between range(30,600):0.32731321017920245
# 0.32731321017920245

# %%
def stdNBgraph(dataset):
        # Coverted to standard Normal Distribution
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    z_score=[((j-mean)/std) for j in values]

    sns.distplot(z_score,kde=True)

    sum(z_score)/len(z_score)
    #z_score.std()

# %%
stdNBgraph(des_data['Low','RELIANCE.NS'])
# Out:
# C:\Users\Rajesh\AppData\Local\Temp\ipykernel_11624\2909774602.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %%
def freqTable(columnName,dataset):
    import pandas as pd
    frq=pd.DataFrame()
    frq["Unique_Values"]=dataset[columnName].value_counts().index
    frq["Frequency"]=dataset[columnName].value_counts().values
    frq["Relative_Fre"]=dataset[columnName].value_counts().values/len(dataset[columnName])*100
    frq["Cumulative"]=frq["Relative_Fre"].cumsum()
    return frq

# %%
freqTable(('Low','RELIANCE.NS'),des_data)
# Out:
#    Unique_Values  Frequency  Relative_Fre  Cumulative
# 0            122          2         12.50       12.50
# 1    1097.584704          2         12.50       25.00
# 2     992.228728          2         12.50       37.50
# 3              0          1          6.25       43.75
# 4    1090.087266          1          6.25       50.00
# 5        43.3439          1          6.25       56.25
# 6    1056.865796          1          6.25       62.50
# 7    1121.747524          1          6.25       68.75
# 8    1165.277051          1          6.25       75.00
# 9      64.881728          1          6.25       81.25
# 10     97.322592          1          6.25       87.50
# 11    959.543204          1          6.25       93.75
# 12   1219.070115          1          6.25      100.00

# %%
freqTable(('High','RELIANCE.NS'),des_data)
# Out:
#    Unique_Values  Frequency  Relative_Fre  Cumulative
# 0            122          2         12.50       12.50
# 1    1113.241998          2         12.50       25.00
# 2    1010.434788          2         12.50       37.50
# 3              0          1          6.25       43.75
# 4    1107.204296          1          6.25       50.00
# 5      41.700961          1          6.25       56.25
# 6    1074.235547          1          6.25       62.50
# 7    1137.859995          1          6.25       68.75
# 8    1186.122956          1          6.25       75.00
# 9      63.624448          1          6.25       81.25
# 10     95.436672          1          6.25       87.50
# 11    978.798874          1          6.25       93.75
# 12   1233.296667          1          6.25      100.00

# %%
fh=freqTable(('High','RELIANCE.NS'),des_data)

# %%
fh.sort_values(by="Frequency",ascending=False)
# Out:
#    Unique_Values  Frequency  Relative_Fre  Cumulative
# 0            122          2         12.50       12.50
# 1    1113.241998          2         12.50       25.00
# 2    1010.434788          2         12.50       37.50
# 3              0          1          6.25       43.75
# 4    1107.204296          1          6.25       50.00
# 5      41.700961          1          6.25       56.25
# 6    1074.235547          1          6.25       62.50
# 7    1137.859995          1          6.25       68.75
# 8    1186.122956          1          6.25       75.00
# 9      63.624448          1          6.25       81.25
# 10     95.436672          1          6.25       87.50
# 11    978.798874          1          6.25       93.75
# 12   1233.296667          1          6.25      100.00

# %%
fhs=fh[fh["Frequency"]==2]["Unique_Values"].sort_values(ascending=False)

# %%
fhs
# Out:
# 1    1113.241998
# 2    1010.434788
# 0            122
# Name: Unique_Values, dtype: object
